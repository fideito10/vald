# %%
import requests
import json

def probar_conexion_vald():
    """Prueba la conexión básica a la API de VALD"""
    
    # Configuración
    CLIENT_ID = "Nr37673W7ncT4qBQ=="  # Reemplaza con tu ID
    CLIENT_SECRET = "EMiYKddb7wKrwgxxLqopECDpkNLiS1XOEaw="  # Reemplaza con tu Secret
    TOKEN_URL = "https://security.valdperformance.com/connect/token"
    
    # Datos para solicitar el token
    payload = {
        "grant_type": "client_credentials",
        "client_id": CLIENT_ID,
        "client_secret": CLIENT_SECRET
    }
    
    try:
        # Intento de conexión
        print("🔄 Intentando conexión con VALD API...")
        response = requests.post(TOKEN_URL, data=payload)
        
        # Verificar respuesta
        if response.status_code == 200:
            token_data = response.json()
            print(token_data)
            print("✅ Conexión exitosa!")
            print("\nDetalles del token:")
            print(f"- Tipo: {token_data.get('token_type', 'No especificado')}")
            print(f"- Expira en: {token_data.get('expires_in', 'No especificado')} segundos")
            print(f"- Token: {token_data.get('access_token', 'No especificado')}")
            return True
        else:
            print("❌ Error en la conexión")
            print(f"Código de estado: {response.status_code}")
            print(f"Mensaje: {response.text}")
            return False
            
    except Exception as e:
        print(f"❌ Error inesperado: {str(e)}")
        return False

if __name__ == "__main__":
    probar_conexion_vald()
# Out:
# 🔄 Intentando conexión con VALD API...
# ...

# %%
import requests
import json
import base64

def probar_conexion_vald():
    """Prueba la conexión básica a la API de VALD"""
    
    # Configuración
    CLIENT_ID = "Nr37673W7ncT4qBQ=="  # Tu ID
    CLIENT_SECRET = "EMiYKddb7wKrwgxxLqopECDpkNLiS1XOEaw="  # Tu Secret
    TOKEN_URL = "https://security.valdperformance.com/connect/token"
    
    # Crear headers con autenticación básica
    credentials = f"{CLIENT_ID}:{CLIENT_SECRET}"
    encoded_credentials = base64.b64encode(credentials.encode()).decode()
    
    headers = {
        "Authorization": f"Basic {encoded_credentials}",
        "Content-Type": "application/x-www-form-urlencoded"
    }
    
    # Datos para solicitar el token
    payload = {
        "grant_type": "client_credentials"
    }
    
    try:
        print("\n🔍 Información de la petición:")
        print(f"URL: {TOKEN_URL}")
        print("Headers:", json.dumps(headers, indent=2))
        print("Payload:", json.dumps(payload, indent=2))
        
        # Intento de conexión
        print("\n🔄 Intentando conexión con VALD API...")
        response = requests.post(TOKEN_URL, headers=headers, data=payload)
        
        # Verificar respuesta
        print(f"\n📡 Código de respuesta: {response.status_code}")
        print(f"📝 Headers de respuesta: {dict(response.headers)}")
        
        if response.status_code == 200:
            token_data = response.json()
            print("\n✅ Conexión exitosa!")
            print("\nDetalles del token:")
            print(f"- Tipo: {token_data.get('token_type', 'No especificado')}")
            print(f"- Expira en: {token_data.get('expires_in', 'No especificado')} segundos")
            return True
        else:
            print("\n❌ Error en la conexión")
            print(f"Mensaje: {response.text}")
            return False
            
    except Exception as e:
        print(f"\n❌ Error inesperado: {str(e)}")
        return False

if __name__ == "__main__":
    probar_conexion_vald()
# Out:
# 🔍 Información de la petición:
# URL: https://security.valdperformance.com/connect/token
# Headers: {
#   "Authorization": "Basic TnIzNzY3M1c3bmNUNHFCUT09OkVNaVlLZGRiN3dLcndneHhMcW9wRUNEcGtOTGlTMVhPRWF3PQ==",
#   "Content-Type": "application/x-www-form-urlencoded"
# }
# Payload: {
#   "grant_type": "client_credentials"
# }
#
# 🔄 Intentando conexión con VALD API...
#
# 📡 Código de respuesta: 200
# 📝 Headers de respuesta: {'Content-Type': 'application/json; charset=UTF-8', 'Date': 'Tue, 15 Apr 2025 15:43:36 GMT', 'Cache-Control': 'no-store, no-cache, max-age=0', 'Content-Encoding': 'gzip', 'Pragma': 'no-cache', 'Transfer-Encoding': 'chunked', 'Vary': 'Accept-Encoding', 'Request-Context': 'appId=cid-v1:96228f5b-548c-44a3-97cb-410f88a353c9'}
#
# ✅ Conexión exitosa!
#
# Detalles del token:
# - Tipo: Bearer
# - Expira en: 7200 segundos

# %%
import base64
import requests
import json

#nticarte  # El token que obtuviste al autenticarte

token="eyJhbGciOiJSUzI1NiIsImtpZCI6IkQ5QTM3MUY2NDBGM0JBQUQ2NDdBRjg5RTc3RDJDMzhBOERFOUQ5MjFSUzI1NiIsIng1dCI6IjJhTng5a0R6dXExa2V2aWVkOUxEaW8zcDJTRSIsInR5cCI6ImF0K2p3dCJ9..wQVoyzYqT8HGRN7_6V7POvPs2pzZEgi4pReDX3-pUrDNjOzQZGzOJQU9XsCUOC45R86nVJxuBtVKbBYe5hmgYF-Hcvgb_4yB7aOEWpJOFqGSXXQIUkVvjUl49ckdhX3C-33bn9OGEwmk7koD_1gJb38T65qvB_cDGP-i8meXw2qLm83xJn-w_wS_H-Q9bhKFynSMtIltADtaUlMuhA8NjdiMHd1MNNEzUSEOx_Krzv2w-3vfg5lbhuIBj8QXSlhpXXk3AZwplocC8omF7T3WyPSCbUc4R7GPRUz8TF4qNc7z-FD-qDWnBPiCp6HA_mE2nRR5GRHIqqY2soKfMrlperRMiaiUUBNKtdWaQJFKVvgYRxyc5-VLS9_BhpYbrHzBp1BnJ1qrMa_uE9kwIf16WvXoG2VBA5MvTErLJjTCl0ckXwxNWAlBig-FrPa5CIg7C1okhkklBtI9RxqSTz00dNDwHKH3S6mbvEamQpxRP1hQrLnCZLpdhHyM4YS4yBsaql_fmAPqacUHs--RG87vhmCe31Yws51IJAFDHYfLpbtf50Hgna63M9gAuFBG2pP3ygZPIPqTW5G3AgLQbbF_U5htwOpzH245B7ibwhLbhRzCqwP1dfVuRzpl2BwqlZgvKYfNuvTmDojyuXysmUowvYWcq4-y6o1Jx2PYQGxXkd8"
# Selecciona la URL correcta según tu región
base_url = "https://prd-aue-api-externaltenants.valdperformance.com"  # Ejemplo para Australia East

# Endpoint para obtener tenants
endpoint = "/tenants"

# Configuración de headers con el token de autenticación
headers = {
    "Authorization": f"Bearer {token}"
}

# Realizar la solicitud HTTP
response = requests.get(f"{base_url}{endpoint}", headers=headers)

# Verificar y mostrar el resultado
if response.status_code == 200:
    # Imprimir respuesta cruda para entender la estructura
    print("Respuesta cruda:")
    print(response.text)
    
    try:
        # Intentar analizar como JSON
        tenants = response.json()
        
        # Verificar si es una lista o un objeto
        if isinstance(tenants, list):
            print(f"\nNúmero de tenants obtenidos: {len(tenants)}")
            
            # Mostrar información de cada tenant
            for i, tenant in enumerate(tenants):
                print(f"\nTenant {i+1}:")
                print(f"  ID: {tenant['id'] if 'id' in tenant else 'No ID'}")
                print(f"  Nombre: {tenant['name'] if 'name' in tenant else 'No Name'}")
        elif isinstance(tenants, dict):
            # Si es un objeto y no una lista
            print("\nTenant obtenido:")
            print(f"  ID: {tenants.get('id', 'No ID')}")
            print(f"  Nombre: {tenants.get('name', 'No Name')}")
        else:
            print(f"\nTipo de dato inesperado: {type(tenants)}")
            print(tenants)
    except json.JSONDecodeError:
        # Si no es JSON válido
        print("\nLa respuesta no es un JSON válido")
        
else:
    print(f"Error: {response.status_code}")
    print(response.text)
# Out:
# Respuesta cruda:
# {"tenants":[{"id":"f1185650-fb79-44a0-8b4b-b2bf82d28c83","name":"STAFF - Luciano Tomagheli"}]}
#
# Tenant obtenido:
#   ID: No ID
#   Nombre: No Name

# %%
import requests

# Variables que necesitas configurar
# token = 'mi token'  # El token que obtuviste al autenticarte
tenant_id = "f1185650-fb79-44a0-8b4b-b2bf82d28c83"  # ID de tu organización
modified_from_utc = "2023-01-01T00:00:00.000Z"  # Fecha desde la que quieres obtener datos

# Selecciona la URL correcta según tu región
base_url = "https://prd-aue-api-externalnordbord.valdperformance.com"  # Ejemplo para Australia East

# Endpoint y parámetros para obtener tests
endpoint = "/tests/v2"
params = {
    "tenantId": tenant_id,
    "modifiedFromUtc": modified_from_utc
}

# Configuración de headers con el token de autenticación
headers = {
    "Authorization": f"Bearer {token}"
}

# Realizar la solicitud HTTP
response = requests.get(f"{base_url}{endpoint}", params=params, headers=headers)

# Verificar y mostrar el resultado
if response.status_code == 200:
    tests = response.json()
    
    # Primero, veamos qué tipo de datos nos devuelve
    print(f"Tipo de respuesta: {type(tests)}")
    
    # Imprimir la estructura de la respuesta para entenderla mejor
    print("\nEstructura de la respuesta:")
    if isinstance(tests, dict):
        for key in tests:
            print(f"Clave: {key}, Tipo: {type(tests[key])}")
    
    # Si es un diccionario que contiene una lista de tests
    if isinstance(tests, dict) and 'items' in tests:
        test_items = tests['items']
        print(f"\nNúmero de tests obtenidos: {len(test_items)}")
        
        # Mostrar información básica de los primeros 5 tests (o menos)
        for i, test in enumerate(test_items[:min(5, len(test_items))]):
            print(f"\nTest {i+1}:")
            print(f"  ID: {test.get('id')}")
            print(f"  Fecha: {test.get('testDateUtc')}")
            print(f"  Perfil: {test.get('profileId')}")
    
    # Si es una lista directamente
    elif isinstance(tests, list):
        print(f"\nNúmero de tests obtenidos: {len(tests)}")
        
        # Mostrar información básica de los primeros 5 tests (o menos)
        for i, test in enumerate(tests[:min(5, len(tests))]):
            print(f"\nTest {i+1}:")
            print(f"  ID: {test.get('id')}")
            print(f"  Fecha: {test.get('testDateUtc')}")
            print(f"  Perfil: {test.get('profileId')}")
    
    # Si es otro tipo de estructura
    else:
        print("\nRespuesta completa:")
        print(tests)
        
elif response.status_code == 204:
    print("No hay más registros para obtener.")
else:
    print(f"Error: {response.status_code}")
    print(response.text)
# Out:
# Tipo de respuesta: <class 'dict'>
#
# Estructura de la respuesta:
# Clave: tests, Tipo: <class 'list'>
#
# Respuesta completa:
# ...

# %%
# Obtener la respuesta completa
response_data = response.json()

# Ver toda la estructura del primer test
if 'tests' in response_data and len(response_data['tests']) > 0:
    first_test = response_data['tests'][0]
    print("Estructura completa del primer test:")
    for key, value in first_test.items():
        print(f"- {key}: {value}")
# Out:
# Estructura completa del primer test:
# - profileId: 9cd86ccc-5359-4737-a6af-5216f9e8059a
# - testId: 710db7b2-a619-4cb9-98e6-998880f6cf83
# - modifiedDateUtc: 2023-01-03T21:44:10.564Z
# - testDateUtc: 2023-01-03T21:43:43.406Z
# - testTypeId: 596a6004-553f-4afa-aef0-1474903b462e
# - testTypeName: Nordic
# - notes:
# - device: NordBord-1756
# - leftAvgForce: 248.33333333333331
# - leftImpulse: 2043.0200000000018
# - leftMaxForce: 305.0
# - leftTorque: 119.4075
# - leftCalibration: 0.0
# - leftRepetitions: 3
# - rightAvgForce: 256.66666666666663
# - rightImpulse: 1972.2050000000008
# - rightMaxForce: 312.5
# - rightTorque: 122.34375
# - rightCalibration: 0.0
# - rightRepetitions: 3

# %%
import requests

# Variables que necesitas configurar
# token = 'mi token'  # El token que obtuviste al autenticarte
tenant_id = "f1185650-fb79-44a0-8b4b-b2bf82d28c83"  # ID de tu organización
modified_from_utc = "2023-01-01T00:00:00.000Z"  # Fecha desde la que quieres obtener datos

# Selecciona la URL correcta según tu región
base_url = "https://prd-aue-api-externalnordbord.valdperformance.com"  # Ejemplo para Australia East

# Endpoint y parámetros para obtener tests
endpoint = "/tests/v2"
params = {
    "tenantId": tenant_id,
    "modifiedFromUtc": modified_from_utc
}

# Configuración de headers con el token de autenticación
headers = {
    "Authorization": f"Bearer {token}"
}

# Realizar la solicitud HTTP
response = requests.get(f"{base_url}{endpoint}", params=params, headers=headers)

# Verificar y mostrar el resultado
if response.status_code == 200:
    tests = response.json()
    
    # Primero, veamos qué tipo de datos nos devuelve
    print(f"Tipo de respuesta: {type(tests)}")
    
    # Imprimir la estructura de la respuesta para entenderla mejor
    print("\nEstructura de la respuesta:")
    if isinstance(tests, dict):
        for key in tests:
            print(f"Clave: {key}, Tipo: {type(tests[key])}")
    
    # Si es un diccionario que contiene una lista de tests
    if isinstance(tests, dict) and 'items' in tests:
        test_items = tests['items']
        print(f"\nNúmero de tests obtenidos: {len(test_items)}")
        
        # Mostrar información básica de los primeros 5 tests (o menos)
        for i, test in enumerate(test_items[:min(5, len(test_items))]):
            print(f"\nTest {i+1}:")
            print(f"  ID: {test.get('id')}")
            print(f"  Fecha: {test.get('testDateUtc')}")
            print(f"  Perfil: {test.get('profileId')}")
    
    # Si es una lista directamente
    elif isinstance(tests, list):
        print(f"\nNúmero de tests obtenidos: {len(tests)}")
        
        # Mostrar información básica de los primeros 5 tests (o menos)
        for i, test in enumerate(tests[:min(5, len(tests))]):
            print(f"\nTest {i+1}:")
            print(f"  ID: {test.get('id')}")
            print(f"  Fecha: {test.get('testDateUtc')}")
            print(f"  Perfil: {test.get('profileId')}")
    
    # Si es otro tipo de estructura
    else:
        print("\nRespuesta completa:")
        print(tests)
        
elif response.status_code == 204:
    print("No hay más registros para obtener.")
else:
    print(f"Error: {response.status_code}")
    print(response.text)
# Out:
# Tipo de respuesta: <class 'dict'>
#
# Estructura de la respuesta:
# Clave: tests, Tipo: <class 'list'>
#
# Respuesta completa:
# ...

# %%
import requests
import json
from requests.exceptions import RequestException

# Configuración
token="eyJhbGciOiJSUzI1NiIsImtpZCI6IkQ5QTM3MUY2NDBGM0JBQUQ2NDdBRjg5RTc3RDJDMzhBOERFOUQ5MjFSUzI1NiIsIng1dCI6IjJhTng5a0R6dXExa2V2aWVkOUxEaW8zcDJTRSIsInR5cCI6ImF0K2p3dCJ9..h1N9OzAwXgKrIk5JHfNZQP30K0vStUg-BILsz2bq2ICd114qWxrpm4XX8kulHDeXKr4wETjAqD1KRADIgaJQJCxt1xWLcB3Yqk8H4gG5d1D5Q1_ZN8YgMWq_wDci14JyrXIM8AtoBcB8CnclW8CVYfm4Yo7JM_zguozX7SOlHyAqTu0Bga9o7G53CPMdyesOaZ9vv0V3RlzhrHnWqwb3wLpRQfmAh1u5R-owlezFAIr590u6k74Pra4cT_suspzWCey740QcEyjM0QiJYB1jbl34Ze-PkeOyLYxLQkFMX_fFwCGw7EfmPFZnyBHmXgRfgZ1vMDSf-I-VLhPG1XnjydG0-_nUaZP3ronX_Rnp3XsPSTnMshpoJuANzQfiIFpaIovQozXb_x9RKnAcG57EDY-8yzFqlg9wYnnw-xRg8961tZpmbDWVFGzCY1vRf90mKN-JP3nZl1HOubyWrpIMSep1SrPr2vFG6pw-FGp_HaIUlalv1OplgGfL-ThVQBm07bpUXNViARTTRNzPCwWXij3lZ9Be4chHN5Ym9Gj6rcqxuCkgDE9p12YT-FLsbDDLYvB01asTbXFAbaIbfqvP1I3ZkG-qhLxj49OE0ufrdj7aLhisTolFDvycXvM2aPI9cB5tIrpbC4jcdpt98vytR--BxOWnlZCgEIZsIT_U0PM"  # Reemplaza con tu token de autenticación
tenant_id = "f1185650-fb79-44a0-8b4b-b2bf82d28c83"
modified_from_utc = "2023-01-01T00:00:00.000Z"
base_url = "https://prd-aue-api-externalnordbord.valdperformance.com"

# Realizar solicitud HTTP con manejo de errores
url = f"{base_url}/tests/v2"
headers = {"Authorization": f"Bearer {token}"}
params = {"tenantId": tenant_id, "modifiedFromUtc": modified_from_utc}

try:
    response = requests.get(url, params=params, headers=headers, timeout=30)
    
    # Procesar respuesta
    if response.status_code == 200:
        data = response.json()
        
        # Verificar el tipo de respuesta
        print(f"Tipo de respuesta: {type(data)}")
        
        # Manejar diferentes estructuras de respuesta
        if isinstance(data, dict):
            if 'items' in data:
                # Si es un diccionario con una lista de items
                tests = data['items']
                print(f"Se encontraron {len(tests)} tests")
                for i, test in enumerate(tests[:min(5, len(tests))]):
                    print(f"\nTest {i+1}:")
                    print(f"  ID: {test.get('id')}")
                    print(f"  Fecha: {test.get('testDateUtc')}")
                    print(f"  Perfil: {test.get('profileId')}")
            else:
                # Si es un único test en formato diccionario
                print("Se encontró 1 test")
                print("\nTest 1:")
                print(f"  ID: {data.get('id')}")
                print(f"  Fecha: {data.get('testDateUtc')}")
                print(f"  Perfil: {data.get('profileId')}")
        elif isinstance(data, list):
            # Si es una lista de tests
            print(f"Se encontraron {len(data)} tests")
            for i, test in enumerate(data[:min(5, len(data))]):
                print(f"\nTest {i+1}:")
                print(f"  ID: {test.get('id')}")
                print(f"  Fecha: {test.get('testDateUtc')}")
                print(f"  Perfil: {test.get('profileId')}")
        else:
            print("Formato de respuesta no reconocido")
            print(data)
            
    elif response.status_code == 204:
        print("No hay registros para obtener.")
    elif response.status_code == 500:
        print("Error 500: Error interno del servidor")
        print("Detalles de la respuesta:")
        try:
            error_details = response.json()
            print(json.dumps(error_details, indent=2))
        except:
            print(response.text)
        print("\nSugerencias para solucionar el error 500:")
        print("1. Verifica que el token de autenticación sea válido y no haya expirado")
        print("2. Confirma que el tenant_id sea correcto")
        print("3. Asegúrate que el formato de fecha modified_from_utc sea válido")
        print("4. Contacta al soporte técnico de Vald si el problema persiste")
    else:
        print(f"Error {response.status_code}: {response.text}")

except RequestException as e:
    print(f"Error de conexión: {e}")
except Exception as e:
    print(f"Error inesperado: {e}")
# Out:
# Error 401:

# %%
import requests
import json
import pandas as pd
from requests.exceptions import RequestException

# Configuración
token="eyJhbGciOiJSUzI1NiIsImtpZCI6IkQ5QTM3MUY2NDBGM0JBQUQ2NDdBRjg5RTc3RDJDMzhBOERFOUQ5MjFSUzI1NiIsIng1dCI6IjJhTng5a0R6dXExa2V2aWVkOUxEaW8zcDJTRSIsInR5cCI6ImF0K2p3dCJ9..wQVoyzYqT8HGRN7_6V7POvPs2pzZEgi4pReDX3-pUrDNjOzQZGzOJQU9XsCUOC45R86nVJxuBtVKbBYe5hmgYF-Hcvgb_4yB7aOEWpJOFqGSXXQIUkVvjUl49ckdhX3C-33bn9OGEwmk7koD_1gJb38T65qvB_cDGP-i8meXw2qLm83xJn-w_wS_H-Q9bhKFynSMtIltADtaUlMuhA8NjdiMHd1MNNEzUSEOx_Krzv2w-3vfg5lbhuIBj8QXSlhpXXk3AZwplocC8omF7T3WyPSCbUc4R7GPRUz8TF4qNc7z-FD-qDWnBPiCp6HA_mE2nRR5GRHIqqY2soKfMrlperRMiaiUUBNKtdWaQJFKVvgYRxyc5-VLS9_BhpYbrHzBp1BnJ1qrMa_uE9kwIf16WvXoG2VBA5MvTErLJjTCl0ckXwxNWAlBig-FrPa5CIg7C1okhkklBtI9RxqSTz00dNDwHKH3S6mbvEamQpxRP1hQrLnCZLpdhHyM4YS4yBsaql_fmAPqacUHs--RG87vhmCe31Yws51IJAFDHYfLpbtf50Hgna63M9gAuFBG2pP3ygZPIPqTW5G3AgLQbbF_U5htwOpzH245B7ibwhLbhRzCqwP1dfVuRzpl2BwqlZgvKYfNuvTmDojyuXysmUowvYWcq4-y6o1Jx2PYQGxXkd8"
tenant_id = "f1185650-fb79-44a0-8b4b-b2bf82d28c83"
modified_from_utc = "2023-01-01T00:00:00.000Z"
base_url = "https://prd-aue-api-externalnordbord.valdperformance.com"

# Realizar solicitud HTTP con manejo de errores
url = f"{base_url}/tests/v2"
headers = {"Authorization": f"Bearer {token}"}
params = {"tenantId": tenant_id, "modifiedFromUtc": modified_from_utc}

try:
    response = requests.get(url, params=params, headers=headers, timeout=30)
    
    # Procesar respuesta
    if response.status_code == 200:
        data = response.json()
        
        # Extraer los tests según la estructura de la respuesta
        if isinstance(data, dict):
            if 'items' in data:
                tests = data['items']
            else:
                # Si es un único test, lo ponemos en una lista para tratarlo igual
                tests = [data]
        elif isinstance(data, list):
            tests = data
        else:
            tests = []
            print("Formato de respuesta no reconocido")
            print(data)
        
        # Crear DataFrame de pandas
        df = pd.DataFrame(tests)
        
        # Mostrar información básica del DataFrame
        print(f"Se encontraron {len(df)} tests")
        print("\nColumnas del DataFrame:")
        print(df.columns.tolist())
        
        print("\nPrimeras 5 filas del DataFrame:")
        print(df.head())
        
        # Explorar estructura anidada (si hay columnas con diccionarios o listas)
        print("\nEstructura detallada:")
        for column in df.columns:
            if df[column].dtype == 'object' and len(df) > 0:
                sample = df[column].iloc[0]
                if isinstance(sample, dict) or isinstance(sample, list):
                    print(f"\nLa columna '{column}' contiene objetos JSON anidados")
                    print(f"Ejemplo del primer registro: {json.dumps(sample, indent=2)[:200]}...")
        
        # Ejemplo de cómo extraer datos de columnas anidadas
        # (Adaptar según la estructura real de tus datos)
        print("\nEjemplo de extracción de datos anidados:")
        for column in df.columns:
            if df[column].dtype == 'object' and len(df) > 0:
                sample = df[column].iloc[0]
                if isinstance(sample, dict):
                    print(f"\nExtrayendo datos de la columna '{column}':")
                    # Creamos un DataFrame temporal con los datos anidados
                    temp_df = pd.json_normalize(df[column].tolist())
                    print(f"Subcolumnas disponibles: {temp_df.columns.tolist()[:5]}...")
                    
                    # Ejemplo para añadir una columna extraída al DataFrame principal
                    # (descomentar y adaptar según necesidades)
                    # if 'campo_importante' in temp_df.columns:
                    #     df[f"{column}_campo_importante"] = temp_df['campo_importante']
        
        print("\nDataFrame creado y listo para análisis!")
        # El DataFrame 'df' ya está disponible para usar
            
    elif response.status_code == 204:
        print("No hay registros para obtener.")
        df = pd.DataFrame()  # DataFrame vacío
    else:
        print(f"Error {response.status_code}: {response.text}")
        df = pd.DataFrame()  # DataFrame vacío

except RequestException as e:
    print(f"Error de conexión: {e}")
    df = pd.DataFrame()  # DataFrame vacío
except Exception as e:
    print(f"Error inesperado: {e}")
    df = pd.DataFrame()  # DataFrame vacío

# Ahora puedes trabajar con 'df' que contiene todos los datos de los tests
# Ejemplo: guardar a CSV
# df.to_csv('vald_tests.csv', index=False)
# Out:
# Se encontraron 1 tests
#
# Columnas del DataFrame:
# ['tests']
#
# Primeras 5 filas del DataFrame:
#                                                tests
# 0  [{'profileId': '9cd86ccc-5359-4737-a6af-5216f9...
#
# Estructura detallada:
#
# La columna 'tests' contiene objetos JSON anidados
# Ejemplo del primer registro: [
#   {
#     "profileId": "9cd86ccc-5359-4737-a6af-5216f9e8059a",
#     "testId": "710db7b2-a619-4cb9-98e6-998880f6cf83",
#     "modifiedDateUtc": "2023-01-03T21:44:10.564Z",
#     "testDateUtc": "2023-01-03T2...
#
# Ejemplo de extracción de datos anidados:
#
# DataFrame creado y listo para análisis!

# %%
df
# Out:
#                                                tests
# 0  [{'profileId': '9cd86ccc-5359-4737-a6af-5216f9...

# %%
import pandas as pd
from pandas import json_normalize

# Normalizar el JSON a DataFrame
def normalizar_json(data):
    # Si es un diccionario con 'items' (formato común de APIs)
    if isinstance(data, dict) and 'items' in data:
        df = pd.DataFrame(data['items'])
    # Si es una lista directamente
    elif isinstance(data, list):
        df = pd.DataFrame(data)
    # Si es un diccionario sin 'items'
    else:
        df = pd.DataFrame([data])
    
    print(f"DataFrame creado con {len(df)} filas y {len(df.columns)} columnas")
    return df

# Normalizar campos anidados específicos
def normalizar_campo(df, campo):
    if campo not in df.columns:
        print(f"El campo '{campo}' no existe en el DataFrame")
        return None
    
    # Tomar el primer valor para ver su estructura
    primer_valor = df[campo].dropna().iloc[0] if len(df[campo].dropna()) > 0 else None
    
    # Si es una lista, expandirla
    if isinstance(primer_valor, list):
        # Expandir la lista a filas
        df_expandido = df.explode(campo)
        # Normalizar a columnas
        df_normalizado = json_normalize(df_expandido[campo].tolist())
        # Añadir ID para relacionar
        if 'id' in df_expandido.columns:
            df_normalizado['id_original'] = df_expandido['id'].values
        return df_normalizado
    
    # Si es un diccionario
    elif isinstance(primer_valor, dict):
        # Normalizar directamente
        return json_normalize(df[campo].tolist())
    
    else:
        print(f"El campo '{campo}' no contiene JSON anidado")
        return None

# Uso:
# 1. Normalizar el JSON principal
df = normalizar_json(data)
print(df.head())

# 2. Normalizar un campo específico (ejemplo)
# Reemplaza 'nombre_campo' con el nombre real del campo anidado
# campo_normalizado = normalizar_campo(df, 'nombre_campo')
# if campo_normalizado is not None:
#     print(campo_normalizado.head())
# Out:
# DataFrame creado con 1 filas y 1 columnas
#                                                tests
# 0  [{'profileId': '9cd86ccc-5359-4737-a6af-5216f9...

# %%
import pandas as pd
import os
from datetime import datetime

def exportar_df_a_csv(df, nombre_base="vald_data", carpeta_destino=None, aplanar_columnas=True, 
                      fecha_en_nombre=True, indice=False, columnas_a_expandir=None):
    """
    Exporta un DataFrame que contiene JSON anidado a un archivo CSV prolijo.
    
    Parámetros:
    -----------
    df : pandas.DataFrame
        El DataFrame a exportar
    nombre_base : str
        Nombre base para el archivo CSV
    carpeta_destino : str
        Ruta donde guardar el archivo (si es None, usa el directorio actual)
    aplanar_columnas : bool
        Si es True, intenta expandir automáticamente columnas con objetos anidados
    fecha_en_nombre : bool
        Si es True, añade fecha y hora al nombre del archivo
    indice : bool
        Si es True, incluye el índice del DataFrame en el CSV
    columnas_a_expandir : list
        Lista de nombres de columnas específicas a expandir manualmente
        
    Retorna:
    --------
    str: Ruta completa del archivo CSV generado
    """
    # Crear una copia del DataFrame para no modificar el original
    df_procesado = df.copy()
    
    # Si carpeta_destino no existe, crearla
    if carpeta_destino is not None:
        os.makedirs(carpeta_destino, exist_ok=True)
    else:
        carpeta_destino = ""
        
    # Aplanar columnas con JSON anidado
    columnas_expandidas = []
    
    # Expansión automática de columnas anidadas si se solicita
    if aplanar_columnas:
        for columna in df_procesado.columns:
            # Verificar si la columna contiene diccionarios o listas
            if df_procesado[columna].dtype == 'object' and len(df_procesado) > 0:
                primer_valor = df_procesado[columna].dropna().iloc[0] if len(df_procesado[columna].dropna()) > 0 else None
                
                if isinstance(primer_valor, dict):
                    # Expandir diccionarios a columnas
                    print(f"Expandiendo columna anidada: {columna}")
                    columnas_expandidas.append(columna)
                    
                    # Usar json_normalize para extraer campos del diccionario
                    temp_df = pd.json_normalize(df_procesado[columna].tolist())
                    
                    # Añadir cada campo como una nueva columna con prefijo
                    for subcol in temp_df.columns:
                        df_procesado[f"{columna}_{subcol}"] = temp_df[subcol]
                    
                    # Opcional: eliminar la columna original con el diccionario
                    # df_procesado.drop(columns=[columna], inplace=True)
                
                elif isinstance(primer_valor, list) and len(primer_valor) > 0:
                    # Para listas simples, podría intentar concatenarlas en una cadena
                    if all(isinstance(item, (str, int, float)) for item in primer_valor):
                        print(f"Convirtiendo lista en columna {columna} a texto")
                        df_procesado[columna] = df_procesado[columna].apply(
                            lambda x: "|".join(str(i) for i in x) if isinstance(x, list) else x
                        )
    
    # Expansión manual de columnas específicas
    if columnas_a_expandir:
        for columna in columnas_a_expandir:
            if columna in df_procesado.columns and columna not in columnas_expandidas:
                try:
                    print(f"Expandiendo columna solicitada: {columna}")
                    # Similar al proceso anterior pero para columnas específicas
                    if df_procesado[columna].dtype == 'object':
                        valores_no_nulos = df_procesado[columna].dropna()
                        if len(valores_no_nulos) > 0:
                            primer_valor = valores_no_nulos.iloc[0]
                            
                            if isinstance(primer_valor, dict):
                                temp_df = pd.json_normalize(df_procesado[columna].tolist())
                                for subcol in temp_df.columns:
                                    df_procesado[f"{columna}_{subcol}"] = temp_df[subcol]
                except Exception as e:
                    print(f"Error al expandir columna {columna}: {str(e)}")
    
    # Formatear nombre de archivo con fecha si se solicita
    if fecha_en_nombre:
        fecha_hora = datetime.now().strftime("%Y%m%d_%H%M%S")
        nombre_archivo = f"{nombre_base}_{fecha_hora}.csv"
    else:
        nombre_archivo = f"{nombre_base}.csv"
    
    # Ruta completa del archivo
    ruta_completa = os.path.join(carpeta_destino, nombre_archivo)
    
    # Exportar a CSV
    df_procesado.to_csv(ruta_completa, index=indice, encoding='utf-8')
    
    print(f"✅ Archivo CSV generado correctamente: {ruta_completa}")
    print(f"📊 Dimensiones: {df_procesado.shape[0]} filas x {df_procesado.shape[1]} columnas")
    
    return ruta_completa

# Ejemplo de uso:
# ruta_csv = exportar_df_a_csv(df, nombre_base="vald_tests", carpeta_destino="datos_exportados")

# %%
# Exportar el DataFrame actual con configuración básica
ruta_archivo = exportar_df_a_csv(df, nombre_base="vald_tests")

# Exportar a una carpeta específica
ruta_archivo = exportar_df_a_csv(df, 
                                nombre_base="vald_tests", 
                                carpeta_destino="datos_exportados")

# Expandir columnas específicas que contienen datos anidados
ruta_archivo = exportar_df_a_csv(df, 
                                nombre_base="vald_tests", 
                                columnas_a_expandir=["metadata", "testData"])
# Out:
# ✅ Archivo CSV generado correctamente: vald_tests_20250415_125612.csv
# 📊 Dimensiones: 1 filas x 1 columnas
# ✅ Archivo CSV generado correctamente: datos_exportados\vald_tests_20250415_125612.csv
# 📊 Dimensiones: 1 filas x 1 columnas
# ✅ Archivo CSV generado correctamente: vald_tests_20250415_125612.csv
# 📊 Dimensiones: 1 filas x 1 columnas

# %%
import json
import pandas as pd
import os
from datetime import datetime
from collections import defaultdict

def leer_json_por_linea(ruta_archivo):
    """Lee un archivo JSON que contiene un objeto JSON por línea.
    
    Args:
        ruta_archivo (str): Ruta al archivo JSON.
        
    Returns:
        list: Lista de objetos JSON.
    """
    datos = []
    try:
        with open(ruta_archivo, 'r', encoding='utf-8') as archivo:
            for linea in archivo:
                linea = linea.strip()
                if linea:  # Omitir líneas vacías
                    try:
                        objeto_json = json.loads(linea)
                        datos.append(objeto_json)
                    except json.JSONDecodeError as e:
                        print(f"Error al decodificar línea: {e}")
                        print(f"Línea problemática: {linea[:100]}...")
        print(f"✅ Se leyeron {len(datos)} objetos JSON del archivo")
    except Exception as e:
        print(f"❌ Error al leer el archivo: {e}")
    
    return datos

def aplanar_diccionario(diccionario, prefijo=''):
    """Aplana un diccionario anidado a un nivel.
    
    Args:
        diccionario (dict): Diccionario para aplanar.
        prefijo (str): Prefijo para claves anidadas.
        
    Returns:
        dict: Diccionario aplanado.
    """
    items = []
    
    for clave, valor in diccionario.items():
        nueva_clave = f"{prefijo}_{clave}" if prefijo else clave
        
        if isinstance(valor, dict):
            # Si es un diccionario, aplanar recursivamente
            items.extend(aplanar_diccionario(valor, nueva_clave).items())
        elif isinstance(valor, list):
            # Si es una lista, manejarla según su contenido
            if valor and all(isinstance(item, dict) for item in valor):
                # Lista de diccionarios: usar el índice como parte de la clave
                for i, item in enumerate(valor):
                    items.extend(aplanar_diccionario(item, f"{nueva_clave}_{i}").items())
            else:
                # Lista simple: convertir a string
                if valor:  # Si la lista no está vacía
                    items.append((nueva_clave, json.dumps(valor)))
                else:
                    items.append((nueva_clave, ""))
        else:
            # Valor simple
            items.append((nueva_clave, valor))
    
    return dict(items)

def aplanar_lista_diccionarios(lista_diccionarios):
    """Aplana una lista de diccionarios potencialmente anidados.
    
    Args:
        lista_diccionarios (list): Lista de diccionarios para aplanar.
        
    Returns:
        list: Lista de diccionarios aplanados.
    """
    return [aplanar_diccionario(diccionario) for diccionario in lista_diccionarios]

def json_a_dataframe(datos_json, aplanar=True):
    """Convierte datos JSON a un DataFrame de pandas.
    
    Args:
        datos_json (list/dict): Datos JSON para convertir.
        aplanar (bool): Si se deben aplanar estructuras anidadas.
        
    Returns:
        pandas.DataFrame: DataFrame resultante.
    """
    # Si es un solo diccionario, conviértelo a una lista con un elemento
    if isinstance(datos_json, dict):
        datos_json = [datos_json]
    
    # Si está vacío, devolver DataFrame vacío
    if not datos_json:
        return pd.DataFrame()
    
    # Aplanar los datos si se solicita
    if aplanar:
        datos_aplanados = aplanar_lista_diccionarios(datos_json)
    else:
        datos_aplanados = datos_json
    
    # Crear DataFrame
    df = pd.DataFrame(datos_aplanados)
    
    print(f"✅ DataFrame creado con {len(df)} filas y {len(df.columns)} columnas")
    return df

def guardar_dataframe_csv(df, nombre_archivo, carpeta_destino=None, fecha_en_nombre=True, indice=False):
    """Guarda un DataFrame en un archivo CSV.
    
    Args:
        df (pandas.DataFrame): DataFrame a guardar.
        nombre_archivo (str): Nombre base del archivo.
        carpeta_destino (str): Carpeta donde guardar el archivo.
        fecha_en_nombre (bool): Si se debe añadir fecha al nombre.
        indice (bool): Si se debe incluir el índice.
        
    Returns:
        str: Ruta del archivo guardado.
    """
    # Crear carpeta destino si no existe
    if carpeta_destino:
        os.makedirs(carpeta_destino, exist_ok=True)
    else:
        carpeta_destino = ""
    
    # Añadir fecha al nombre si se solicita
    if fecha_en_nombre:
        fecha_hora = datetime.now().strftime("%Y%m%d_%H%M%S")
        nombre_completo = f"{nombre_archivo}_{fecha_hora}.csv"
    else:
        nombre_completo = f"{nombre_archivo}.csv"
    
    # Ruta completa
    ruta_completa = os.path.join(carpeta_destino, nombre_completo)
    
    # Guardar DataFrame
    df.to_csv(ruta_completa, index=indice, encoding='utf-8')
    
    print(f"✅ Archivo guardado: {ruta_completa}")
    print(f"📊 Dimensiones: {df.shape[0]} filas x {df.shape[1]} columnas")
    
    return ruta_completa

# Ejemplo de uso completo
def procesar_archivo_json_a_csv(ruta_entrada, nombre_salida, carpeta_destino=None):
    """Procesa un archivo JSON línea por línea y lo guarda como CSV.
    
    Args:
        ruta_entrada (str): Ruta del archivo JSON a procesar.
        nombre_salida (str): Nombre base para el archivo CSV resultante.
        carpeta_destino (str): Carpeta donde guardar el CSV.
        
    Returns:
        str: Ruta del archivo CSV generado.
    """
    print(f"🔄 Procesando el archivo: {ruta_entrada}")
    
    # Leer el archivo JSON
    datos = leer_json_por_linea(ruta_entrada)
    
    if not datos:
        print("❌ No se encontraron datos para procesar")
        return None
    
    # Convertir a DataFrame
    df = json_a_dataframe(datos)
    
    # Guardar como CSV
    ruta_csv = guardar_dataframe_csv(df, nombre_salida, carpeta_destino)
    
    return ruta_csv

# %%
# Ejemplo de uso:
# Reemplaza 'ruta_del_archivo.json' con la ruta de tu archivo JSON
# ruta_archivo_json = 'ruta_del_archivo.json'
# ruta_csv = procesar_archivo_json_a_csv(ruta_archivo_json, 'datos_aplanados', 'datos_procesados')

# También puedes usar las funciones por separado:
# 1. Leer el archivo JSON
# datos = leer_json_por_linea(ruta_archivo_json)
# 
# 2. Convertir a DataFrame
# df = json_a_dataframe(datos)
# 
# 3. Explorar el DataFrame
# print(df.head())
# 
# 4. Guardar como CSV
# guardar_dataframe_csv(df, 'datos_aplanados', 'datos_procesados')

# %%
# Función avanzada para manejar casos especiales en la estructura JSON

def normalizar_columnas_especificas(df, columnas_a_expandir=None, max_nivel=3):
    """Normaliza columnas específicas que contienen JSON o listas anidadas.
    
    Args:
        df (pandas.DataFrame): DataFrame a procesar.
        columnas_a_expandir (list): Lista de columnas a expandir.
        max_nivel (int): Máximo nivel de anidamiento a procesar.
        
    Returns:
        pandas.DataFrame: DataFrame con columnas normalizadas.
    """
    df_resultado = df.copy()
    
    # Si no se especifican columnas, buscar automáticamente
    if not columnas_a_expandir:
        columnas_a_expandir = []
        for col in df.columns:
            # Verificar si contiene JSON o listas anidadas
            if df[col].dtype == 'object' and df[col].notna().any():
                muestra = df[col].dropna().iloc[0]
                if isinstance(muestra, (dict, list, str)):
                    # Si es string, intentar decodificar como JSON
                    if isinstance(muestra, str):
                        try:
                            json_obj = json.loads(muestra)
                            if isinstance(json_obj, (dict, list)):
                                columnas_a_expandir.append(col)
                        except (json.JSONDecodeError, TypeError):
                            pass
                    else:
                        columnas_a_expandir.append(col)
    
    # Procesar cada columna seleccionada
    for nivel in range(max_nivel):
        for col in columnas_a_expandir.copy():  # Usar copia para poder modificar durante el bucle
            if col in df_resultado.columns:
                try:
                    # Para columnas con strings que son JSON
                    if df_resultado[col].dtype == 'object' and isinstance(df_resultado[col].iloc[0], str):
                        try:
                            # Intentar convertir strings a objetos JSON
                            df_resultado[col] = df_resultado[col].apply(
                                lambda x: json.loads(x) if isinstance(x, str) and x.strip() else x
                            )
                        except (json.JSONDecodeError, TypeError):
                            pass
                    
                    # Normalizar diccionarios
                    if df_resultado[col].apply(lambda x: isinstance(x, dict)).any():
                        # Usar json_normalize para expandir diccionarios
                        dict_norm = pd.json_normalize(df_resultado[col].dropna().tolist())
                        
                        # Añadir nuevas columnas con prefijo
                        for subcol in dict_norm.columns:
                            nueva_col = f"{col}_{subcol}"
                            # Mapear valores a los índices originales
                            mapping = {}
                            for i, (idx, val) in enumerate(df_resultado[col].dropna().items()):
                                if isinstance(val, dict) and subcol in val:
                                    mapping[idx] = val[subcol]
                            
                            # Crear nueva columna
                            if mapping:
                                df_resultado[nueva_col] = df_resultado.index.map(mapping)
                                columnas_a_expandir.append(nueva_col)  # Posible nueva columna a expandir
                        
                        # Opcional: eliminar columna original
                        # df_resultado.drop(columns=[col], inplace=True)
                        columnas_a_expandir.remove(col)  # Ya no necesita ser expandida
                    
                    # Normalizar listas
                    elif df_resultado[col].apply(lambda x: isinstance(x, list)).any():
                        # Expandir listas de forma especial según su contenido
                        primer_elemento = next((x for x in df_resultado[col] if isinstance(x, list) and len(x) > 0), None)
                        
                        if primer_elemento and all(isinstance(item, dict) for item in primer_elemento):
                            # Lista de diccionarios - crear columnas para cada elemento
                            max_items = df_resultado[col].apply(lambda x: len(x) if isinstance(x, list) else 0).max()
                            
                            for i in range(min(max_items, 5)):  # Limitar a 5 elementos por defecto
                                # Extraer elemento i de cada lista
                                serie_elemento = df_resultado[col].apply(
                                    lambda x: x[i] if isinstance(x, list) and len(x) > i else None
                                )
                                
                                if serie_elemento.notna().any():
                                    # Normalizar este elemento
                                    dict_norm = pd.json_normalize(serie_elemento.dropna().tolist())
                                    
                                    # Añadir columnas con prefijo
                                    for subcol in dict_norm.columns:
                                        nueva_col = f"{col}_{i}_{subcol}"
                                        # Mapear valores
                                        mapping = {}
                                        for idx, val in serie_elemento.items():
                                            if isinstance(val, dict) and subcol in val:
                                                mapping[idx] = val[subcol]
                                        
                                        if mapping:
                                            df_resultado[nueva_col] = df_resultado.index.map(mapping)
                        else:
                            # Lista de valores simples - convertir a string separado por pipe
                            df_resultado[col] = df_resultado[col].apply(
                                lambda x: "|".join(str(i) for i in x) if isinstance(x, list) else x
                            )
                        
                        columnas_a_expandir.remove(col)  # Ya procesada
                    
                except Exception as e:
                    print(f"Error al procesar columna '{col}': {e}")
    
    return df_resultado

# %%
# Ejemplo específico para procesar datos de VALD

# Si tienes datos en una variable (como los que obtuviste de la API)
if 'response_data' in globals() and response_data:
    print("Procesando datos de respuesta existente...")
    
    # Verificar si hay datos en 'tests'
    if 'tests' in response_data and response_data['tests']:
        # Extraer los tests
        tests_data = response_data['tests']
        
        # Convertir a DataFrame
        df_tests = pd.DataFrame(tests_data)
        print(f"DataFrame creado con {len(df_tests)} tests y {len(df_tests.columns)} columnas")
        
        # Mostrar primeras filas
        display(df_tests.head())
        
        # Guardar como CSV
        ruta_csv = guardar_dataframe_csv(df_tests, 'vald_tests', 'datos_vald')
        print(f"Datos guardados en: {ruta_csv}")
    else:
        print("No se encontraron tests en los datos de respuesta")
else:
    print("No hay datos de respuesta disponibles")

# %% [markdown]
# # Procesamiento de archivos JSON línea por línea
#
# Las funciones implementadas permiten:
#
# 1. **Leer archivos JSON línea por línea** - Ideal para archivos grandes donde cada línea es un objeto JSON independiente
# 2. **Aplanar estructuras anidadas** - Convierte estructuras jerárquicas en formato plano
# 3. **Normalizar datos** - Expande campos anidados en columnas separadas
# 4. **Exportar a CSV** - Guarda los resultados en formato tabular
#
# ## Ejemplo de uso:
#
# ```python
# # Procesar archivo
# ruta_csv = procesar_archivo_json_a_csv('datos.json', 'resultados')
#
# # Importar datos y explorar
# df = pd.read_csv(ruta_csv)
# df.head()
# ```
#
# Para casos con estructuras más complejas, usar la función `normalizar_columnas_especificas`.
