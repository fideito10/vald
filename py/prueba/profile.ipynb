# %%
import requests
import json

def probar_conexion_vald():
    """Prueba la conexión básica a la API de VALD"""
    
    # Configuración
    CLIENT_ID = "Nr37673W7ncT4qBQ=="  # Reemplaza con tu ID
    CLIENT_SECRET = "EMiYKddb7wKrwgxxLqopECDpkNLiS1XOEaw="  # Reemplaza con tu Secret
    TOKEN_URL = "https://security.valdperformance.com/connect/token"
    
    # Datos para solicitar el token
    payload = {
        "grant_type": "client_credentials",
        "client_id": CLIENT_ID,
        "client_secret": CLIENT_SECRET
    }
    
    try:
        # Intento de conexión
        print("🔄 Intentando conexión con VALD API...")
        response = requests.post(TOKEN_URL, data=payload)
        
        # Verificar respuesta
        if response.status_code == 200:
            token_data = response.json()
            print(token_data)
            print("✅ Conexión exitosa!")
            print("\nDetalles del token:")
            print(f"- Tipo: {token_data.get('token_type', 'No especificado')}")
            print(f"- Expira en: {token_data.get('expires_in', 'No especificado')} segundos")
            print(f"- Token: {token_data.get('access_token', 'No especificado')}")
            return True
        else:
            print("❌ Error en la conexión")
            print(f"Código de estado: {response.status_code}")
            print(f"Mensaje: {response.text}")
            return False
            
    except Exception as e:
        print(f"❌ Error inesperado: {str(e)}")
        return False

if __name__ == "__main__":
    probar_conexion_vald()
# Out:
# 🔄 Intentando conexión con VALD API...
# ...

# %%
import requests

# Token ya generado (cuidado con el vencimiento)
token = "eyJhbGciOiJSUzI1NiIsImtpZCI6IkQ5QTM3MUY2NDBGM0JBQUQ2NDdBRjg5RTc3RDJDMzhBOERFOUQ5MjFSUzI1NiIsIng1dCI6IjJhTng5a0R6dXExa2V2aWVkOUxEaW8zcDJTRSIsInR5cCI6ImF0K2p3dCJ9..mT5UFD3J_B2rqlrYAifObdGVSpmydXdCoFXNtAWyIlL4H6fUtopZPwXwWeg22EXNz2pWV7nN_wpTVbrDVzrSZI9Qwd1Jjq4eY_PeF_NVPUyxGbmM2yDMgR4kNs84i-zL5wPRsxepnuCr8aLUQCdoa8deYsIE-AG71XmkMfofuFJmUntJzN_QMEPURTDHiBrxk5jZ2Q_mRyLgNCRXVccmwZkQXbzSuus7qPZbwsvHnaf5CdFTDkU1Qmx5TQzVV6256z1WBThxTVaCpTH9hb7XK9nZva0Qo3Qhj_exrqVjQSD0VaCottV8zrrpY3XJN8GUq9YmCVI51tWPHjPpiJfniNoRJVYEER6ycYSrqna8LKbpjjvdjU3NTY5eoXCcStyipfpuOCgR-c2ZeUFwoLRJEKbBLLhCBxcxA6kgafEuZ3iVQWpsABs1ry2GD4KGaHkfs0BsPG7vjqH2lRMhVNvKtlaYv-V93hytf9t_u_Y3omepbiL3isQBJPpNA53L8yKBD6bMEQe54POtl6vDet0elvi751EgeVGE5seAm61TiIFkOSAID27xf4uj6LLh7K2zSVIeH0nJFlF2owcGelfqOOHTTMFyOZXDTMbxtj_nOyK6mXILbH02SoYUgWTGocW9uaV5rgWF5izbrP_KNxqbojJdYSjTnE-kVPoPkEZqMn0"


# Tu tenantId
tenant_id = "f1185650-fb79-44a0-8b4b-b2bf82d28c83"

# Endpoint base
url = "https://prd-aue-api-externalprofile.valdperformance.com/profiles"

# Headers de autenticación
headers = {
    "Authorization": f"Bearer {token}",
    "Accept": "application/json"
}

# Parámetros que se mandan en la URL (query params)
params = {
    "tenantId": tenant_id
}

# Request GET con token y tenantId
response = requests.get(url, headers=headers, params=params)

# Procesamos la respuesta
if response.status_code == 200:
    perfiles = response.json()
    print("✅ Perfiles recibidos:")
    for perfil in perfiles:
        print(f"🧍‍♂️ {perfil['givenName']} {perfil['familyName']} - ID: {perfil['id']}")
elif response.status_code == 401:
    print("🔒 Token inválido o vencido.")
elif response.status_code == 403:
    print("⛔ No tenés permisos suficientes.")
elif response.status_code == 400:
    print("⚠️ Faltan parámetros obligatorios.")
    print(response.text)
else:
    print(f"⚠️ Error {response.status_code}")
    print(response.text)
# Out:
# ✅ Perfiles recibidos:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 32
#      30     print("✅ Perfiles recibidos:")
#      31     for perfil in perfiles:
# ---> 32         print(f"🧍‍♂️ {perfil['givenName']} {perfil['familyName']} - ID: {perfil['id']}")
#      33 elif response.status_code == 401:
#      34     print("🔒 Token inválido o vencido.")
#
# TypeError: string indices must be integers, not 'str'

# %%
# Nueva celda para extraer perfiles con mejor manejo de errores
import requests
import pandas as pd
import json

def extraer_perfiles(token, tenant_id):
    """
    Extrae perfiles de la API de VALD y los convierte a DataFrame
    """
    # URL y configuración
    url = "https://prd-aue-api-externalprofile.valdperformance.com/profiles"
    headers = {
        "Authorization": f"Bearer {token}",
        "Accept": "application/json"
    }
    params = {
        "tenantId": tenant_id
    }
    
    print("🔄 Consultando perfiles de VALD...")
    
    # Realizar la solicitud
    try:
        response = requests.get(url, headers=headers, params=params)
        print(f"📊 Código de respuesta: {response.status_code}")
        
        if response.status_code == 200:
            # Intentar decodificar como JSON
            try:
                # Examinar el tipo de la respuesta
                contenido = response.json()
                print(f"Tipo de respuesta: {type(contenido)}")
                
                # Si es una lista (array de perfiles)
                if isinstance(contenido, list):
                    print(f"✅ Se encontraron {len(contenido)} perfiles")
                    
                    # Mostrar los perfiles en formato tabla
                    if len(contenido) > 0:
                        # Extraer información relevante para un DataFrame
                        datos_perfiles = []
                        for perfil in contenido:
                            try:
                                datos_perfiles.append({
                                    'ID': perfil.get('id', 'N/A'),
                                    'Nombre': perfil.get('givenName', 'N/A'),
                                    'Apellido': perfil.get('familyName', 'N/A'),
                                    'Email': perfil.get('email', 'N/A'),
                                    'Sexo': perfil.get('sex', 'N/A'),
                                    'Fecha Nacimiento': perfil.get('dateOfBirth', 'N/A')
                                })
                            except Exception as e:
                                print(f"⚠️ Error procesando un perfil: {str(e)}")
                                print(f"Perfil problemático: {perfil}")
                        
                        # Crear DataFrame y mostrar
                        df_perfiles = pd.DataFrame(datos_perfiles)
                        print("\n📋 Tabla de perfiles:")
                        return df_perfiles
                    else:
                        print("⚠️ No se encontraron perfiles")
                        return pd.DataFrame()
                
                # Si es un objeto (podría ser un error o un solo perfil)
                elif isinstance(contenido, dict):
                    print("⚠️ La respuesta es un objeto único, no una lista de perfiles")
                    print(json.dumps(contenido, indent=2))
                    return pd.DataFrame([contenido])
                
                # Otro tipo de respuesta
                else:
                    print(f"⚠️ Formato de respuesta inesperado: {type(contenido)}")
                    print(contenido)
                    return None
                    
            except json.JSONDecodeError:
                print("❌ Error decodificando JSON")
                print(f"Respuesta: {response.text[:200]}...")
                return None
                
        elif response.status_code == 401:
            print("🔒 Token inválido o vencido")
            return None
        elif response.status_code == 403:
            print("⛔ No tienes permisos suficientes")
            return None
        else:
            print(f"❌ Error {response.status_code}")
            print(f"Mensaje: {response.text[:200]}...")
            return None
            
    except Exception as e:
        print(f"❌ Error en la solicitud: {str(e)}")
        return None

# Ejecutar la función con los parámetros existentes
df_perfiles = extraer_perfiles(token, tenant_id)
if df_perfiles is not None and not df_perfiles.empty:
    display(df_perfiles)
# Out:
# 🔄 Consultando perfiles de VALD...
# 📊 Código de respuesta: 200
# Tipo de respuesta: <class 'dict'>
# ⚠️ La respuesta es un objeto único, no una lista de perfiles
# {
#   "profiles": [
#     {
#       "profileId": "9536b6e1-7e91-42ee-ba10-007652696924",
#       "syncId": null,
#       "givenName": "Francisco",
#       "familyName": "Angeli",
#       "dateOfBirth": "2004-01-17T00:00:00",
#       "externalId": null
#     },
#     {
#       "profileId": "ee1a0a72-db5f-40fa-a3e3-0087883bd7b8",
#       "syncId": null,
#       "givenName": "Dario",
#       "familyName": "Colman",
#       "dateOfBirth": "2007-03-15T00:00:00",
#       "externalId": null
#     },
#     {
#       "profileId": "8edbc2ea-ce5b-4ccf-80f2-00b1073ac137",
#       "syncId": null,
#       "givenName": "Valentin",
#       "familyName": "Cuccioli",
#       "dateOfBirth": "2002-06-01T00:00:00",
#       "externalId": null
#     },
#     {
#       "profileId": "2f661931-3b4a-45f9-a539-00f396859d15",
#       "syncId": null,
# ...

# %%
# Función simplificada para extraer perfiles de VALD API
import requests
import pandas as pd
import json

def obtener_token():
    """Obtiene un token de autenticación para la API de VALD"""
    CLIENT_ID = "Nr37673W7ncT4qBQ=="
    CLIENT_SECRET = "EMiYKddb7wKrwgxxLqopECDpkNLiS1XOEaw="
    TOKEN_URL = "https://security.valdperformance.com/connect/token"
    
    payload = {
        "grant_type": "client_credentials",
        "client_id": CLIENT_ID,
        "client_secret": CLIENT_SECRET
    }
    
    try:
        response = requests.post(TOKEN_URL, data=payload)
        if response.status_code == 200:
            return response.json().get('access_token')
        else:
            print(f"Error obteniendo token: {response.status_code}")
            return None
    except Exception as e:
        print(f"Error en la conexión: {str(e)}")
        return None

def extraer_perfiles(token=None, tenant_id="f1185650-fb79-44a0-8b4b-b2bf82d28c83"):
    """Extrae perfiles de VALD API y devuelve un DataFrame con los datos"""
    # Si no se proporciona token, intenta obtener uno nuevo
    if not token:
        token = obtener_token()
        if not token:
            return None

    # Configuración de la solicitud
    url = "https://prd-aue-api-externalprofile.valdperformance.com/profiles"
    headers = {"Authorization": f"Bearer {token}", "Accept": "application/json"}
    params = {"tenantId": tenant_id}
    
    try:
        # Realizar la solicitud
        response = requests.get(url, headers=headers, params=params)
        
        if response.status_code == 200:
            perfiles = response.json()
            
            # Convertir los perfiles a un DataFrame
            if isinstance(perfiles, list) and perfiles:
                datos = []
                for p in perfiles:
                    datos.append({
                        'ID': p.get('id', 'N/A'),
                        'Nombre': p.get('givenName', 'N/A'),
                        'Apellido': p.get('familyName', 'N/A'),
                        'Email': p.get('email', 'N/A'),
                        'Sexo': p.get('sex', 'N/A')
                    })
                return pd.DataFrame(datos)
            else:
                print("No se encontraron perfiles.")
                return pd.DataFrame()
        else:
            print(f"Error: {response.status_code}")
            print(response.text)
            return None
    except Exception as e:
        print(f"Error en la solicitud: {str(e)}")
        return None

# Ejecutar y mostrar resultados
df = extraer_perfiles()
if df is not None and not df.empty:
    print(f"Se encontraron {len(df)} perfiles:")
    display(df)
# Out:
# No se encontraron perfiles.

# %%
# Solución para el error "No se encontraron perfiles"
import requests
import pandas as pd
import json
from datetime import datetime

# 1. Primero, obtenemos un token nuevo para asegurarnos que es válido
def obtener_nuevo_token():
    print("🔑 Obteniendo un token nuevo...")
    CLIENT_ID = "Nr37673W7ncT4qBQ=="
    CLIENT_SECRET = "EMiYKddb7wKrwgxxLqopECDpkNLiS1XOEaw="
    TOKEN_URL = "https://security.valdperformance.com/connect/token"
    
    payload = {
        "grant_type": "client_credentials",
        "client_id": CLIENT_ID,
        "client_secret": CLIENT_SECRET
    }
    
    try:
        response = requests.post(TOKEN_URL, data=payload)
        if response.status_code == 200:
            token = response.json().get('access_token')
            print("✅ Token obtenido correctamente")
            return token
        else:
            print(f"❌ Error obteniendo token: {response.status_code}")
            print(response.text)
            return None
    except Exception as e:
        print(f"❌ Error en la conexión: {str(e)}")
        return None

# 2. Función para verificar perfiles con diagnóstico detallado
def verificar_perfiles(token, tenant_id="f1185650-fb79-44a0-8b4b-b2bf82d28c83"):
    """Verifica detalladamente la respuesta de perfiles para diagnóstico"""
    url = "https://prd-aue-api-externalprofile.valdperformance.com/profiles"
    headers = {"Authorization": f"Bearer {token}", "Accept": "application/json"}
    params = {"tenantId": tenant_id}
    
    print(f"🔍 Verificando perfiles en tenant: {tenant_id}")
    print(f"📝 URL: {url}")
    print(f"🔒 Usando token: {token[:20]}...{token[-10:]}")
    
    try:
        print("📡 Enviando solicitud...")
        response = requests.get(url, headers=headers, params=params)
        print(f"📩 Código de estado: {response.status_code}")
        
        # Intentamos mostrar parte de la respuesta cruda
        print("\n📄 Primeros 300 caracteres de la respuesta:")
        print(response.text[:300])
        
        if response.status_code == 200:
            try:
                data = response.json()
                print(f"\n🔢 Tipo de datos recibidos: {type(data)}")
                
                if isinstance(data, list):
                    print(f"📊 Total de elementos en la lista: {len(data)}")
                    if len(data) > 0:
                        print("\n✅ Primer elemento encontrado:")
                        print(json.dumps(data[0], indent=2))
                        
                        # Convertir a DataFrame
                        datos = []
                        for p in data:
                            datos.append({
                                'ID': p.get('id', 'N/A'),
                                'Nombre': p.get('givenName', 'N/A'),
                                'Apellido': p.get('familyName', 'N/A'),
                                'Email': p.get('email', 'N/A'),
                                'Sexo': p.get('sex', 'N/A')
                            })
                        return pd.DataFrame(datos)
                    else:
                        print("⚠️ La lista está vacía - no hay perfiles disponibles")
                elif isinstance(data, dict):
                    print("\n⚠️ La respuesta es un objeto, no una lista:")
                    print(json.dumps(data, indent=2))
                else:
                    print(f"⚠️ Formato inesperado: {type(data)}")
            except json.JSONDecodeError:
                print("❌ Error al decodificar JSON - respuesta no válida")
        else:
            print("❌ La solicitud no fue exitosa")
            
    except Exception as e:
        print(f"❌ Error en la solicitud: {str(e)}")
    
    return None

# 3. Ejecutamos la solución completa
nuevo_token = obtener_nuevo_token()
if nuevo_token:
    print("\n🔄 Usando el nuevo token para verificar perfiles...")
    df_perfiles = verificar_perfiles(nuevo_token)
    
    if df_perfiles is not None and not df_perfiles.empty:
        print(f"\n✅ Se encontraron {len(df_perfiles)} perfiles:")
        display(df_perfiles)
    else:
        print("\n❌ No se pudieron recuperar los perfiles.")
        print("👉 Posibles soluciones:")
        print("   1. Verifica el tenant ID")
        print("   2. Confirma que tienes los permisos correctos")
        print("   3. Asegúrate que existen perfiles en el sistema")
        print("   4. Revisa la documentación de la API")
else:
    print("❌ No se pudo obtener un nuevo token")
# Out:
# 🔑 Obteniendo un token nuevo...
# ✅ Token obtenido correctamente
#
# 🔄 Usando el nuevo token para verificar perfiles...
# 🔍 Verificando perfiles en tenant: f1185650-fb79-44a0-8b4b-b2bf82d28c83
# 📝 URL: https://prd-aue-api-externalprofile.valdperformance.com/profiles
# 🔒 Usando token: eyJhbGciOiJSUzI1NiIs...oNrfXELQxg
# 📡 Enviando solicitud...
# 📩 Código de estado: 200
#
# 📄 Primeros 300 caracteres de la respuesta:
# {"profiles":[{"profileId":"9536b6e1-7e91-42ee-ba10-007652696924","syncId":null,"givenName":"Francisco","familyName":"Angeli","dateOfBirth":"2004-01-17T00:00:00","externalId":null},{"profileId":"ee1a0a72-db5f-40fa-a3e3-0087883bd7b8","syncId":null,"givenName":"Dario","familyName":"Colman","dateOfBirth
#
# 🔢 Tipo de datos recibidos: <class 'dict'>
#
# ⚠️ La respuesta es un objeto, no una lista:
# {
#   "profiles": [
#     {
#       "profileId": "9536b6e1-7e91-42ee-ba10-007652696924",
#       "syncId": null,
#       "givenName": "Francisco",
#       "familyName": "Angeli",
# ...

# %%
df_perfiles

# %%
df
# Out:
#                                  profileId syncId     Nombre Completo  \
# 0     9536b6e1-7e91-42ee-ba10-007652696924   None   Angeli, Francisco
# 1     ee1a0a72-db5f-40fa-a3e3-0087883bd7b8   None       Colman, Dario
# 2     8edbc2ea-ce5b-4ccf-80f2-00b1073ac137   None  Cuccioli, Valentin
# 3     2f661931-3b4a-45f9-a539-00f396859d15   None      Buglione, Ivan
# 4     6399adfd-4baa-4a2d-b220-00ffda5924d5   None    MAISONNAVE, IVAN
# ...                                    ...    ...                 ...
# 1630  d905e01d-7776-45de-9e83-ff6431f330a5   None       Urtaiz, Tadeo
# 1631  a5517bb4-9d2b-46d0-8c28-ffa190f72ed4   None      Nu�ez, Gabriel
# 1632  4d8de9eb-bd5a-46af-8cc4-ffc1f480483e   None     ocello, nicolas
# 1633  b76fe412-2ce0-4a34-9bc5-ffdd8920abfb   None        Boix, Renata
# 1634  c1afa599-ecf1-46b0-ab07-ffe9dfe37f5d   None       Erlynch, Joel
#
#      Fecha de nacimiento       Dni
# 0             2004-01-17      None
# 1             2007-03-15      None
# ...

# %%
# Procesamiento completo de perfiles VALD a CSV
import pandas as pd
import json
from datetime import datetime

# Definir función que procesa todo el proceso de extracción a CSV
def procesar_perfiles_a_csv(perfiles_dict):
    """
    Procesa los perfiles de VALD, normaliza datos y los guarda en CSV
    
    Args:
        perfiles_dict: Diccionario con datos de perfiles VALD
    """
    # 1. Extraer la lista de perfiles del diccionario
    profiles_list = perfiles_dict.get('profiles', [])
    
    # 2. Crear DataFrame normalizado
    df = pd.json_normalize(profiles_list)
    
    if df.empty:
        print("⚠️ No hay perfiles para procesar")
        return None
        
    # 3. Formatear columnas de fecha
    for col in df.columns:
        if 'date' in col.lower():
            try:
                df[col] = pd.to_datetime(df[col]).dt.strftime('%Y-%m-%d')
            except:
                pass  # Mantener formato original si falla la conversión
    
    # 4. Renombrar columnas para mejor legibilidad
    df = df.rename(columns={
        'profileId': 'profileId',
        'syncId': 'syncId', 
        'givenName': 'nombre',
        'familyName': 'apellido',
        'dateOfBirth': 'Fecha de nacimiento',
        'externalId': 'Dni'
    })
    
    # 5. Crear columna de nombre completo y reorganizar
    df['Nombre Completo'] = df['apellido'] + ', ' + df['nombre']
    
    # 6. Eliminar columnas originales de nombre y apellido
    df = df.drop(['nombre', 'apellido'], axis=1)
    
    # 7. Reordenar columnas según especificación
    columnas_disponibles = df.columns.tolist()
    columns_order = [col for col in ['profileId', 'syncId', 'Nombre Completo', 
                                     'Fecha de nacimiento', 'Dni'] if col in columnas_disponibles]
    
    # Agregar cualquier otra columna que no esté en el orden especificado
    for col in columnas_disponibles:
        if col not in columns_order:
            columns_order.append(col)
    
    df = df[columns_order]
    
    # 8. Guardar a CSV con timestamp
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    filename = f"perfiles_vald_{timestamp}.csv"
    df.to_csv(filename, index=False, encoding='utf-8')
    
    print(f"✅ Archivo guardado como: {filename}")
    print(f"📊 Total de perfiles procesados: {len(df)}")
    
    return df

# Ejecutar el procesamiento con los datos de perfiles
# (Asumiendo que 'perfiles' es tu variable que contiene el diccionario)
try:
    # Mostrar los primeros perfiles para verificar
    df_procesado = procesar_perfiles_a_csv(perfiles)
    
    if df_procesado is not None:
        print("\n📋 Vista previa de los datos procesados:")
        display(df_procesado.head())
    
except NameError:
    print("❌ La variable 'perfiles' no está definida. Asegúrate de ejecutar primero la celda que obtiene los perfiles.")
except Exception as e:
    print(f"❌ Error durante el procesamiento: {str(e)}")
# Out:
# ✅ Archivo guardado como: perfiles_vald_20250417_192901.csv
# 📊 Total de perfiles procesados: 1635
#
# 📋 Vista previa de los datos procesados:
#                               profileId syncId     Nombre Completo  \
# 0  9536b6e1-7e91-42ee-ba10-007652696924   None   Angeli, Francisco
# 1  ee1a0a72-db5f-40fa-a3e3-0087883bd7b8   None       Colman, Dario
# 2  8edbc2ea-ce5b-4ccf-80f2-00b1073ac137   None  Cuccioli, Valentin
# 3  2f661931-3b4a-45f9-a539-00f396859d15   None      Buglione, Ivan
# 4  6399adfd-4baa-4a2d-b220-00ffda5924d5   None    MAISONNAVE, IVAN
#
#   Fecha de nacimiento       Dni
# 0          2004-01-17      None
# 1          2007-03-15      None
# 2          2002-06-01      None
# 3          2005-01-01      None
# 4          2009-01-20  48982968
